# %%
import pandas as pd
import os

# 📁 Fayllar joylashgan joy: Merging_Data
source_folder = r"C:\Users\Rasulbek907\Desktop\Final_Project\Data\Merging_Data"

# 📄 Fayllar ro'yxati
filenames = [f"hf_dataset{i}.csv" for i in range(1, 19)]

# 📥 CSV fayllarni o'qib birlashtirish
dataframes = []
for file in filenames:
    file_path = os.path.join(source_folder, file)
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        dataframes.append(df)
        print(f"✅ Yuklandi: {file}")
    else:
        print(f"❌ Topilmadi: {file}")

# 🧩 Barchasini birlashtirish
if dataframes:
    merged_df = pd.concat(dataframes, ignore_index=True)

    # 📤 Yangi faylni saqlash manzili (Raw_data papkasi)
    output_path = r"C:\Users\Rasulbek907\Desktop\Final_Project\Data\Raw_data\merged_dataset.csv"
    merged_df.to_csv(output_path, index=False, encoding='utf-8')

    print(f"\n✅ Yangi fayl saqlandi: {output_path}")
else:
    print("\n⚠️ Hech qanday fayl topilmadi yoki yuklanmadi.")
# Out:
# ✅ Yuklandi: hf_dataset1.csv
# ✅ Yuklandi: hf_dataset2.csv
# ✅ Yuklandi: hf_dataset3.csv
# ✅ Yuklandi: hf_dataset4.csv
# ✅ Yuklandi: hf_dataset5.csv
# ✅ Yuklandi: hf_dataset6.csv
# ✅ Yuklandi: hf_dataset7.csv
# ✅ Yuklandi: hf_dataset8.csv
# ✅ Yuklandi: hf_dataset9.csv
# ✅ Yuklandi: hf_dataset10.csv
# ✅ Yuklandi: hf_dataset11.csv
# ✅ Yuklandi: hf_dataset12.csv
# ✅ Yuklandi: hf_dataset13.csv
# ✅ Yuklandi: hf_dataset14.csv
# ✅ Yuklandi: hf_dataset15.csv
# ✅ Yuklandi: hf_dataset16.csv
# ✅ Yuklandi: hf_dataset17.csv
# ✅ Yuklandi: hf_dataset18.csv
#
# ✅ Yangi fayl saqlandi: C:\Users\Rasulbek907\Desktop\Final_Project\Data\Raw_data\merged_dataset.csv

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Final_Project\Data\Raw_data\merged_dataset.csv")

# %%
df.head()
# Out:
#                        name                        birth_date  \
# 0              Isaac Newton    {{Birth date|df=y|1643|01|04}}
# 1               Marie Curie     {{birth date|df=y|1867|11|7}}
# 2           Albert Einstein   {{Birth date|df=yes|1879|3|14}}
# 3  The Countess of Lovelace    {{birth date|df=y|1815|12|10}}
# 4         Leonardo da Vinci  {{birth date|df=yes|1452|04|15}}
#
#                                          birth_place  \
# 0  {{nowrap|[[Woolsthorpe-by-Colsterworth]],}} Li...
# 1  [[Warsaw]], [[Congress Poland|Poland]], Russia...
# 2  [[Ulm]], [[Kingdom of Württemberg]], Germany<r...
# 3                                    London, England
# 4  possibly [[Anchiano]],{{efn|name=Birthplace}} ...
#
#                                           death_date  \
# 0  {{Death date and age|df=y|1727|03|31|1643|01|04}}
# 1     {{death date and age|df=y|1934|7|4|1867|11|7}}
# 2  {{Death date and age|df=yes|1955|4|18|1879|3|14}}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2022 entries, 0 to 2021
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           2011 non-null   object
#  1   birth_date     1759 non-null   object
#  2   birth_place    1741 non-null   object
#  3   death_date     1239 non-null   object
#  4   death_place    1170 non-null   object
#  5   nationality    233 non-null    object
#  6   occupation     630 non-null    object
#  7   years_active   191 non-null    object
#  8   known_for      238 non-null    object
#  9   awards         382 non-null    object
#  10  alma_mater     335 non-null    object
#  11  education      439 non-null    object
#  12  employer       10 non-null     object
#  13  notable_works  95 non-null     object
#  14  field          228 non-null    object
#  15  spouse         793 non-null    object
#  16  children       522 non-null    object
# ...

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['name', 'birth_date', 'birth_place', 'death_date', 'death_place', 'nationality', 'occupation', 'years_active', 'known_for', 'awards', 'alma_mater', 'education', 'employer', 'notable_works', 'field', 'spouse', 'children', 'parents', 'religion', 'genre']
